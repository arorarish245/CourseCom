# %%
import csv

def read_csv(filename, columns, encoding='utf-8'):
    data = []
    with open(filename, 'r', encoding=encoding) as file:
        reader = csv.DictReader(file)
        for row in reader:
            row_data = [str(row[col]) for col in columns]
            data.append(row_data)
    return data
# Function to write array to a text file
def write_to_text(data, filename, encoding='utf-8', errors='replace'):
    with open(filename, 'w', encoding=encoding, errors=errors) as file:
        file.write('[')
        for i, row in enumerate(data):
            if i > 0:
                file.write(', ')
            file.write('[' + ','.join(row) + ']')
        file.write(']')

# Example usage
csv_filename = 'new.csv'
output_filename = 'final.txt'
selected_columns = ['Course Title', 'Course Url', 'Rating', 'Instructor', 'Offered By', 'Number of Review', ]  # Specify the columns you want to extract
# Read CSV file and extract particular columns
data = read_csv(csv_filename, selected_columns, encoding='utf-8')

# Write the extracted data to a text file
#write_to_text(data, output_filename, encoding='utf-8', errors='replace')
print(data)
# Out:
# [['Fashion as Design', 'https://www.coursera.org/learn/fashion-design', '4.8', 'Anna Burckhardt, Paola Antonelli, Michelle Millar Fisher, Stephanie Kramer', 'The Museum of Modern Art', '2813'], ['Modern American Poetry', 'https://www.coursera.org/learn/modern-american-poetry', '4.4', 'Cary Nelson', 'University of Illinois at Urbana-Champaign', '100'], ['Pixel Art for Video Games', 'https://www.coursera.org/learn/pixel-art-video-games', '4.5', 'Andrew Dennis, Ricardo Guimaraes', 'Michigan State University', '227'], ['Distribución digital de la música independiente', 'https://www.coursera.org/learn/distribucion-digital-de-la-musica-independiente', '0.0', 'Eduardo de la Vara Brown.', 'SAE Institute México', '0'], ['The Blues: Understanding and Performing an American Art Form', 'https://www.coursera.org/learn/the-blues', '4.8', 'Dariusz Terefenko', 'University of Rochester', '582'], ['So You Think You Know Tango?', 'https://www.coursera.org/learn/tango', '4.6', 'Kristin Wendland', 'Emory University', '107'], ['The Politics of Skepticism', 'https://www.coursera.org/learn/erasmus-philosophy-skepticism', '4.5', 'Tim De Mey, Wiep van Bunge', 'Erasmus University Rotterdam', '38'], ['Становлення сучасної України', 'https://www.coursera.org/learn/the-making-of-modern-ukraine-ua', '0.0', 'Timothy Snyder', 'Yale University', '0'], ["Exploring Beethoven's Piano Sonatas Part 4", 'https://www.coursera.org/learn/exploring-beethoven-piano-sonatas-4', '4.9', 'Jonathan Biss', 'Curtis Institute of Music', '63'], ['悖论：思维的魔方', 'https://www.coursera.org/learn/bei-lun', '4.8', '陈波', 'Peking University', '39'], ['拍